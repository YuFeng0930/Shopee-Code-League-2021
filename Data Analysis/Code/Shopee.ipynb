# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_json('contacts.json')

# %%
df
# Out:
#             Id                Email         Phone  Contacts  \
# 0            0       gkzAbIy@qq.com                       1
# 1            1                       329442681752         4
# 2            2                         9125983679         0
# 3            3   mdllpYmE@gmail.com                       0
# 4            4                          300364407         2
# ...        ...                  ...           ...       ...
# 499995  499995                        10072395382         2
# 499996  499996                       571709661031         4
# 499997  499997                         4541459979         2
# 499998  499998  RzSDsyH@hotmail.com   98947185431         1
# 499999  499999                       880053388839         0
#
#                           OrderId
# 0
# 1       vDDJJcxfLtSfkooPhbYnJdxov
# 2
# 3       bHquEnCbbsGLqllwryxPsNOxa
# 4
# ...                           ...
# 499995  whJlUOGNqjxCRzmIRdURQvlNv
# 499996  JqIXOONvrwvJxZqNxCYHqnrKS
# ...

# %%
part_df = df.loc[0:100]
part_df['Contacts']= part_df['Contacts'].values.astype(str)
part_df['Id']= part_df['Id'].values.astype(str)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
part_df
# Out:
#       Id                            Email         Phone Contacts  \
# 0    0    gkzAbIy@qq.com                                 1
# 1    1                                     329442681752  4
# 2    2                                     9125983679    0
# 3    3    mdllpYmE@gmail.com                             0
# 4    4                                     300364407     2
# 5    5                                     840113148     0
# 6    6    hESiBgYTxMnj@hotmail.com                       4
# 7    7    hqyunTiaXfIjhO@yahoo.com                       1
# 8    8    XGUjcSiDpFKWEUCs@qq.com          223604620644  2
# 9    9    osIIQgAiZX@hotmail.com                         0
# 10   10                                    918973512631  3
# 11   11   QRamvop@qq.com                                 0
# 12   12   QexYMLXc@qq.com                                2
# 13   13   YsKhkKGJoQSNniHcr@yahoo.com      562300766     1
# 14   14                                    17423803380   4
# ...

# %%
df_combine = part_df.groupby(['Email','Phone','Contacts','OrderId'])['Id'].apply(', '.join).reset_index()

# %%
df_combine
# Out:
#                                Email         Phone Contacts  \
# 0                                     092607900110  4
# 1                                     148015042798  2
# 2                                     157404533     4
# 3                                     160202795123  3
# 4                                     17423803380   4
# 5                                     200902397     0
# 6                                     2469790597    1
# 7                                     2905688150    4
# 8                                     300364407     2
# 9                                     306249213     0
# 10                                    329442681752  4
# 11                                    350299140     4
# 12                                    387065011     0
# 13                                    38969610017   3
# 14                                    418749991856  3
# 15                                    468981077     4
# ...

# %%
part_df.dtypes
# Out:
# Id          object
# Email       object
# Phone       object
# Contacts    object
# OrderId     object
# dtype: object

# %%
df_combine
# Out:
#                                Email        Phone Contacts   Id
# 0                                     00124685005        0  244
# 1                                     01051644706        4  517
# 2                                     01725772956        3  397
# 3                                     01731400251        2  777
# 4                                     02031532182        3  713
# ...                              ...          ...      ...  ...
# 996         zaOWDcAUVPUu@hotmail.com   6077568766        1  210
# 997   zghscqdrBEDETMNkHrZx@gmail.com                     4  490
# 998          zinblVyMfkjtt@yahoo.com                     1  249
# 999            zmLSdmTwMsw@gmail.com                     0  779
# 1000       zpzShkcgqJuAorkPmL@qq.com                     0  765
#
# [1001 rows x 4 columns]

# %%
df_combine
# Out:
#                                  Email         Phone Contacts    Id
# 0                                       00124685005   0        244
# 1                                       01051644706   4        517
# 2                                       01725772956   3        397
# 3                                       01731400251   2        777
# 4                                       02031532182   3        713
# 5                                       022445555     3        401
# 6                                       024989637880  1        845
# 7                                       025560175640  3        313
# 8                                       026678424     0        589
# 9                                       029296634896  1        844
# 10                                      035866631779  3        545
# 11                                      037315516     4        914
# 12                                      0389738389    2        571
# ...
